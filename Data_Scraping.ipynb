# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.globaldata.com/data-insights/macroeconomic/literacy-rate-in-nigeria/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    print(paragraph.text.strip())
# Out:
# Literacy Rate in Nigeria Overview
# As more people get a better education, Nigeria’s literacy rate has improved. Between 2010-2021, the literacy rate was highest in the year 2021 and lowest in the year 2010. The literacy rate reached 77.62% in 2021. Between 2010 to 2021, the literacy rate of Nigeria grew by 13.9%. On a year-on-year basis, the literacy rate increased by 0.13% in 2021.
# Literacy Rate
# The percentage of the population in each age group who is literate serves as a measure of literacy. The literacy rate for adults is 15 years of age or older, the rate for youth is 15 to 24 years of age, and the rate for the elderly is 65 years of age or older. The ability to comprehend brief, straightforward statements about daily life is typically how it is measured. In general, computing ability is a component of literacy, and basic computation tests may be used as metrics.
# The literacy rate shows how well primary education and literacy programs are working generally, instills fundamental literacy skills in the populace, puts these abilities to use in daily life, and makes it possible for people to master written language and stay in touch. The ability to read and write indicates the potential for greater intellectual development as well as society's economic and socio-cultural advancement.
# Factors that Affect the Literacy Rate
# Around 70% of women and 95% of the world's illiterate populace reside in developing nations. Women have a relatively high percentage of literacy in sub-Saharan Africa. For instance, more than 90% of women are literate in Burkina Faso and Niger. School attendance, lifespan, and birthweight are the three main factors of the global literacy rate.
# Don’t wait - discover a universe of connected data & insights with your next search. Browse over 28M data points across 22 industries.
# Access more premium companies when you subscribe to Explorer

# %%
lists = soup.find_all(['ul', 'ol'])
for list_item in lists:
    print(list_item.text.strip())
# Out:
# Visit Corporate Site
# Sign In
#
#
# Home
#
#
#
#
# Data & Insights
#
#
#
#
#
# Data & Insights
#
#
# View all Data & Insights
#
#
# Advanced Search
#
#
#
#
#
#
# Insight by Sector
#
# Aerospace & Defense
# Automotive
# Agriculture & Forestry
# Business & Consumer Services
# Construction
# Chemicals
# Consumer
# Foodservice
# Financial Services
# Government & Non-profit Organisations
# Healthcare
# Industrial Goods & Machinery
# Mining
# Packaging
# Oil & Gas
# Power & Utilities
# Retail & Wholesale
# Real Estate
# Sports
# Transportation, Infrastructure & Logistics
# Technology, Media & Telecom
# Travel & Tourism
#
#
#
#
#
# Insight Type
#
# Company Performance
# Macro economic
# Other Industry Indicators
# Market Sizing & Shares
# Product Indicators
# Thematic Indicators
# ESG
#
#
#
#
#
#
#
#
# Themes
#
#
#
#
#
# Themes
#
#
# View all Themes
#
#
#
#
#
#
# Key Themes
#
#
#
#
# Artificial Intelligence
# Cloud
# COVID-19
# Cybersecurity
# ESG - Environment
#
#
#
#
#
#
# ESG - Governance
# ESG - Social
# Internet of Things
# Robotics
#
#
#
#
#
#
#
#
#
#
#
#
#                     What will the world look like in 2030?
#                     Anticipate the challenges and opportunities disrupting your industry.
#
#
#
#
#
# View Report
#
#
#
#
#
#
#
#
#
#
# ESG
#
#
#
#
#
# ESG Factors
#
#
# ESG Overview
#
#
# Environment
#
#
# Social
#
#
# Governance
#
#
#
#
#
#
# ESG Trending Topics
#
#
#
#
#                                                             Electric Vehicles
#
#
#
#
#
#
#                                                             Solar
#
#
#
#
#
#
#                                                             Food and Agritech
#
#
#
#
#
#
#                                                             Hydrogen
#
#
#
#
#
#
#                                                             Circular Plastic Economy
#
#
#
#
#
#
#                                                             Edtech
#
#
#
#
#
#
#                                                             Sustainable Healthcare
#
#
#
#
#
#
#                                                             Microfinance
#
#
#
#
#
#
#                                                             Cybersecurity
#
#
#
#
#
#
#                                                             Risk Management
#
#
#
#
#
#
#
#
# Other Resources
#
#
#
# Signals
#
#
#
#
# Company Key Lists
#
#
#
#
# Regulations
#
#
#
#
# Surveys and Polls
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
# Media
#
#
# Investors
#
#
# Careers
#
#
# Contact Us
#
#
# Request a Demo
# Data & Insights
#
#
# View all Data & Insights
#
#
# Advanced Search
#
#
#
#
#
#
# Insight by Sector
#
# Aerospace & Defense
# Automotive
# Agriculture & Forestry
# Business & Consumer Services
# Construction
# Chemicals
# Consumer
# Foodservice
# Financial Services
# Government & Non-profit Organisations
# Healthcare
# Industrial Goods & Machinery
# Mining
# Packaging
# Oil & Gas
# Power & Utilities
# Retail & Wholesale
# Real Estate
# Sports
# Transportation, Infrastructure & Logistics
# Technology, Media & Telecom
# Travel & Tourism
#
#
#
#
#
# Insight Type
#
# Company Performance
# Macro economic
# Other Industry Indicators
# Market Sizing & Shares
# Product Indicators
# Thematic Indicators
# ESG
# Aerospace & Defense
# Automotive
# Agriculture & Forestry
# Business & Consumer Services
# Construction
# Chemicals
# Consumer
# Foodservice
# Financial Services
# Government & Non-profit Organisations
# Healthcare
# Industrial Goods & Machinery
# Mining
# Packaging
# Oil & Gas
# Power & Utilities
# Retail & Wholesale
# Real Estate
# Sports
# Transportation, Infrastructure & Logistics
# Technology, Media & Telecom
# Travel & Tourism
# Company Performance
# Macro economic
# Other Industry Indicators
# Market Sizing & Shares
# Product Indicators
# Thematic Indicators
# ESG
# Themes
#
#
# View all Themes
#
#
#
#
#
#
# Key Themes
#
#
#
#
# Artificial Intelligence
# Cloud
# COVID-19
# Cybersecurity
# ESG - Environment
#
#
#
#
#
#
# ESG - Governance
# ESG - Social
# Internet of Things
# Robotics
#
#
#
#
#
#
#
#
#
#
#
#
#                     What will the world look like in 2030?
#                     Anticipate the challenges and opportunities disrupting your industry.
#
#
#
#
#
# View Report
# Artificial Intelligence
# Cloud
# COVID-19
# Cybersecurity
# ESG - Environment
# ESG - Governance
# ESG - Social
# Internet of Things
# Robotics
# ESG Factors
#
#
# ESG Overview
#
#
# Environment
#
#
# Social
#
#
# Governance
#
#
#
#
#
#
# ESG Trending Topics
#
#
#
#
#                                                             Electric Vehicles
#
#
#
#
#
#
#                                                             Solar
#
#
#
#
#
#
#                                                             Food and Agritech
#
#
#
#
#
#
#                                                             Hydrogen
#
#
#
#
#
#
#                                                             Circular Plastic Economy
#
#
#
#
#
#
#                                                             Edtech
#
#
#
#
#
#
#                                                             Sustainable Healthcare
#
#
#
#
#
#
#                                                             Microfinance
#
#
#
#
#
#
#                                                             Cybersecurity
#
#
#
#
#
#
#                                                             Risk Management
#
#
#
#
#
#
#
#
# Other Resources
#
#
#
# Signals
#
#
#
#
# Company Key Lists
#
#
#
#
# Regulations
#
#
#
#
# Surveys and Polls
# Electric Vehicles
#
#
#
#
#
#
#                                                             Solar
#
#
#
#
#
#
#                                                             Food and Agritech
#
#
#
#
#
#
#                                                             Hydrogen
#
#
#
#
#
#
#                                                             Circular Plastic Economy
#
#
#
#
#
#
#                                                             Edtech
#
#
#
#
#
#
#                                                             Sustainable Healthcare
#
#
#
#
#
#
#                                                             Microfinance
#
#
#
#
#
#
#                                                             Cybersecurity
#
#
#
#
#
#
#                                                             Risk Management
# Signals
#
#
#
#
# Company Key Lists
#
#
#
#
# Regulations
#
#
#
#
# Surveys and Polls
# Home
#
#
# Data & Insights
#
#
# Current:  Macro-economic
# Share on Twitter
#
#
#
#
#  Share on LinkedIn
#
# The literacy rate of Nigeria reached 77.62% in 2021
# Between 2010-2021, the literacy rate was highest in the year 2021
# On a year-on-year basis, the literacy rate increased by 0.13% in 2021
# Hot Topics
#
#
#
#
# Terms & Conditions
#
#
#
#
# Privacy Policy
#
#
#
#
# Contact Us
#
#
#
#
# Sitemap
#
#
#
#
# Modern Slavery Statement

# %%
# Example: Extract table data
table_data = soup.find_all('table')

# %%
print(table_data)
# Out:
# []
